# %% [markdown]
# # Иморт библиотек

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import scipy as sp
#import seaborn as sns

# %%
from collections import Counter

# %% [markdown]
# # Загрузка данных

# %%
points = np.load('points.npy')

# %%
axes().set_ylabel('Image') 
axes().set_xlabel('Real')
scatter(points.real, points.imag)

# %% [markdown]
# # Постановка задачи

# %% [markdown]
# Задано $N=30$ исходных собственных чисел матрицы $A$. Требуется редуцировать порядок системы.
# Если на вход системе подается испульсная дельта-функция Дирака $\delta(\theta - t_0)$, то получаем на выходе
# $$y_k=\sum\limits_{p=1}^{P} \sum\limits_{j=1}^{n_p} \frac{(k \Delta)^{j-1}}{(j-1)!}(f_{p_j}^c \cos k \Delta \beta_p + f_{p_j}^s \sin k \Delta \beta_p) \exp(-\alpha_p k \Delta)$$

# %% [markdown]
# Задача – определить параметры редуцированной системы, а именно $f_q^c, f_q^s, \alpha_q, \beta_q$, когда
# $$\tilde y_k = \sum\limits_{q=1}^Q (f_q^c \cos k \Delta \beta_q + f_q^s \sin k \Delta \beta_q) \exp(-\alpha_q k \Delta)$$

# %% [markdown]
# # Выполнение работы

# %%
def generate_f(size):
    """
    Generates random numbers of given size uniformly in (-1, -0.9) join (0.9, 1).
    """
    arr = random.uniform(0.9, 1.1, size)
    arr[arr > 1] -= 2
    return arr

# %%
def get_impulse_sum(f_c, f_s, alpha, beta, delta=0.05):
    """
    Creates sum calculator with given parameters and returns it.
    """
    def sum_calculator(k):
        coef = f_c * np.cos(k * delta * beta) + f_s * np.sin(k * delta * beta)
        exp_val = np.exp(- alpha * k * delta)
        return np.dot(coef, exp_val)
    return sum_calculator

# %%
def calculate_delta(eigenvalues):
    return min(2 / (5 * max(abs(eigenvalues.real))), np.pi / (5 * max(abs(eigenvalues.real))))

# %%
def generate_initial_impulse(eigenvalues, delta):
    cnt = Counter(eigenvalues)
    unique_eigenvalues = cnt.keys()
    eigen_count = len(unique_eigenvalues)
    f_c, f_s = generate_f((2, eigen_count))
    eigenvalues = concatenate(tuple(repeat(value, cnt[value]) for value in unique_eigenvalues))
    f_cc = concatenate(tuple(repeat(f_c[i], cnt[value]) for i, value in enumerate(unique_eigenvalues)))
    f_ss = concatenate(tuple(repeat(f_s[i], cnt[value]) for i, value in enumerate(unique_eigenvalues)))
    print('Eigenvalues: ', eigenvalues)
    print('f_c: ', f_cc)
    print('f_s: ', f_ss)
    print('Delta: ', delta)
    return vectorize(get_impulse_sum(f_cc, f_ss, -eigenvalues.real, eigenvalues.imag, delta))

# %%
DELTA = calculate_delta(points)

# %%
y_k = generate_initial_impulse(points, DELTA)
# Out:
# Eigenvalues:  [ 0.00000000+0.488119j  0.00000000-0.488119j -4.20594167+3.704083j
#  -3.07762250+3.129952j -4.01719625+4.616544j  0.00000000+3.717795j
#  -4.99519292+5.620215j -2.41375917+5.33778j  -1.49858875-6.442257j
#  -2.63104708+6.993242j -1.49858875+6.442257j  0.00000000+7.478414j
#  -3.65719292-4.976066j -1.03305958+6.197849j -2.41375917-5.33778j
#  -4.99519292-5.620215j  0.00000000-7.478414j -2.63104708-6.993242j
#  -1.03305958-6.197849j -3.35096167+0.j       -4.01719625-4.616544j
#  -1.22275083+3.242653j -4.20594167-3.704083j -3.07762250-3.129952j
#  -1.22275083-3.242653j  0.00000000-3.717795j -3.65719292+4.976066j
#  -3.78557500+0.j       -2.13498583+0.j       -1.97344750+0.j      ]
# f_c:  [-0.91734777  0.91982984  0.90605463 -0.96508725  0.95644367  0.91447432
#   0.97208056 -0.99384421  0.93412551 -0.92153244  0.96737686  0.90359729
#  -0.96702764  0.92661588 -0.91773629  0.95352434 -0.90159226 -0.94127525
#   0.92615119  0.99963003  0.914692    0.93362488  0.90616664  0.93297864
#  -0.90262113  0.95990471 -0.96128513 -0.97715528  0.91388298  0.92018412]
# f_s:  [ 0.9473213   0.97072619 -0.9439257   0.94229114  0.94897997 -0.95161704
#  -0.94997573 -0.90773835  0.98209677 -0.96607282  0.90081809 -0.99382576
#   0.92279846  0.93288607  0.91691132 -0.94563251  0.97055642  0.93027357
#   0.98361693  0.93398494  0.95816817 -0.95777715 -0.91387233  0.92628163
#  -0.94783245 -0.91263972  0.92718098  0.91018127 -0.91853965 -0.97833484]
# Delta:  0.0800769873503

# %%
def generate_cost_func(support, complexity, delta):
    """
    Example approximator.
    """
    value = y_k(support)
    def approximator(vec):
        params = vec.reshape((4, complexity))
        return mean(abs(value -  vectorize(get_impulse_sum(*params, delta))(support)))
    return approximator

# %%
Q = 10
appr = generate_cost_func(arange(0, 500, 1), Q, DELTA)
init_params = concatenate((ones(Q*2), zeros(Q*2)))
solution = sp.optimize.fmin_bfgs(appr, init_params)
print(solution.reshape((4, Q)))
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.555223
#          Iterations: 10
#          Function evaluations: 3951
#          Gradient evaluations: 94
# [[ 0.04761667  0.04761667  0.04761667  0.04761667  0.04761667  0.04761667
#    0.04761667  0.04761667  0.04761667  0.04761667]
#  [ 1.11524594  1.11524594  1.11524594  1.11524594  1.11524594  1.11524594
#    1.11524594  1.11524594  1.11524594  1.11524594]
#  [ 0.43832177  0.43832177  0.43832181  0.43832177  0.43832181  0.43832177
#    0.43832181  0.43832181  0.43832181  0.43832181]
#  [-0.00195333 -0.00195333 -0.00195337 -0.00195333 -0.00195337 -0.00195333
#   -0.00195337 -0.00195337 -0.00195337 -0.00195337]]

# %%
y_appr = vectorize(get_impulse_sum(*solution.reshape((4, Q)), DELTA))

# %%
figure(figsize=(15,10))
X = arange(0, 500, 1)
plot(X, y_k(X))
plot(X, y_appr(X))
show()
